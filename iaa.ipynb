# %%
# from sklearn.metrics import cohen_kappa_score
import pandas as pd
import numpy as np
import os

# %%
base_dir = "/home/beatrice/Documents/ProviderSentiment2024/tiny_sample_01"

os.listdir(base_dir)
# Out:
# ['liam.jsonl', 'kalaila.jsonl', 'aarti.jsonl']

# %%
class NoteCorpus:
    def __init__(self, file_list):
        self.file_dict = self.get_file_dict(file_list)
        self.annotation_dict = self.get_annotation_dict()
        self.df = list(self.file_dict.values())[0].drop(columns=["label"]).copy()
        self.label_dict = None

    def load_label_dict(self, label_dict=None):
        if label_dict is None:
            self.label_dict = label_dict = {
                "FAMILY: Positive": 0,
                "FAMILY: Negative": 1,
                "PROGNOSIS: Positive": 2,
                "PROGNOSIS: Negative": 3,
                "PATIENT: Positive": 4,
                "PATIENT: Negative": 5,
                "EVENT: Family/Goals of Care Meeting": 6,
                "EVENT: Care Withdrawn/Comfort Measures Only": 7
            }
        else:
            self.label_dict = label_dict


    def get_file_dict(self, file_list):
        file_dict = load_all_files(file_list)
        common_id_set = get_common_ids(file_dict)
        return filter_files(file_dict, common_id_set)
    
    def get_annotation_dict(self, ann_col="label"):
        annotation_dict = dict()
        for annotator, data in self.file_dict.items():
            annotation_list = data[ann_col]
            annotation_dict[annotator] = annotation_list

        return annotation_dict
    
    def retrieve_annotations(self, idx):
        annotation_dict_slice = dict()
        for annotator, annotation_list in self.annotation_dict.items():
            annotation_dict_slice[annotator] = annotation_list[idx]

        return annotation_dict_slice

    def build_corpus(self):
        for i, data in self.df.iterrows():
            note = ClinicalNote(data, self.label_dict, self.retrieve_annotations(i))
            break




def load_all_files(file_list):
    file_dict = dict()

    for _file in file_list:
        if _file.endswith(".jsonl"):
            annotator_name = _file.split(".")[0].title()
            file_dict[annotator_name] = pd.read_json(os.path.join(base_dir, _file), lines=True)

    return file_dict

def get_common_ids(file_dict, id_col="ROW_ID"):
    id_list = [set(_file[id_col]) for _file in file_dict.values()]
    common_ids = set.intersection(*id_list)

    return common_ids

def filter_files(file_dict, common_ids, id_col="ROW_ID"):
    filtered_dict = dict()

    for annotator, data in file_dict.items():
        filtered_data = data[data[id_col].isin(common_ids)]
        filtered_dict[annotator] = filtered_data

    return filtered_dict

    
class ClinicalNote:
    def __init__(self, data, label_dict: dict, annotation_dict: dict):
        self.data = data
        self.label_dict = label_dict
        self.n_labels = len(label_dict)
        self.text_len = len(self.data.text)

        self.label_array = None
        self.binary_label_dict = None

        print(annotation_dict)

    def parse_label(self):
        # extract label list
        label_list = self.data.label

        self.label_array = np.zeros((self.text_len, self.n_labels))
        for label in label_list:
            # unpack the elements of the label
            start_idx, end_idx, label = label

            # set the index
            self.label_array[start_idx:end_idx, self.label_dict[label]] = 1

    def binarize_labels(self):
        # get a reverse of the label dict
        idx_dict = {v:k for (k,v) in self.label_dict.items()}
        pred_dict = {k:False for k in self.label_dict.keys()}

        for idx in range(self.n_labels):
            # check if any indexes were predicted to have a label
            label = idx_dict[idx]
            label_pred = np.sum(self.label_array[:, idx]) > 0

            pred_dict[label] = label_pred

        self.binary_label_dict = pred_dict


label_dict = {
    "FAMILY: Positive": 0,
    "FAMILY: Negative": 1,
    "PROGNOSIS: Positive": 2,
    "PROGNOSIS: Negative": 3,
    "PATIENT: Positive": 4,
    "PATIENT: Negative": 5,
    "EVENT: Family/Goals of Care Meeting": 6,
    "EVENT: Care Withdrawn/Comfort Measures Only": 7
}

# %%
file_name_list = os.listdir(base_dir)
file_list = [_file for _file in file_name_list if _file.endswith(".jsonl")]

corpus = NoteCorpus(file_list)
corpus.load_label_dict()

# %%
corpus.build_corpus()
# Out:
# {'Liam': [[347, 363, 'EVENT: Care Withdrawn/Comfort Measures Only'], [384, 410, 'PROGNOSIS: Negative']], 'Kalaila': [[280, 296, 'PROGNOSIS: Negative'], [346, 380, 'EVENT: Care Withdrawn/Comfort Measures Only'], [383, 410, 'PROGNOSIS: Negative'], [483, 593, 'FAMILY: Positive']], 'Aarti': [[332, 356, 'EVENT: Family/Goals of Care Meeting'], [383, 428, 'PROGNOSIS: Negative']]}

# %%
for k, v in corpus.annotation_dict.items():
    print(k)
    print(type(v[0]))
# Out:
# Liam
# <class 'list'>
# Kalaila
# <class 'list'>
# Aarti
# <class 'list'>

# %%
kalaila_df = pd.read_json(os.path.join(base_dir, 'kalaila.jsonl'), lines=True)

kalaila_list = []

for i, data in kalaila_df.iterrows():
    note_obj = ClinicalNote(data, label_dict)
    note_obj.parse_label()
    note_obj.binarize_labels()

    kalaila_list.append(note_obj.binary_label_dict)

# %%
kalaila_df
# Out:
#      id                                               text   ROW_ID  \
# 0   721  Pt is a 69M with h/o HTN, CAD s/p CABG, AVR wi...   415056
# 1   722  A/P 55 yo RHM with a left hemiparesis (leg>arm...   552822
# 2   723  Ms. [**Known lastname 2211**] is a 76-year-old...   544396
# 3   724  45 yo male w/ PMH: R steel plate in leg; hyper...   557478
# 4   725  [**Age over 90 **] y/o M ([**Hospital1 328**] ...   532283
# 5   726  RESP CARE NOTE\nPT REMAINS ON SAME VENT SETTIN...  1652831
# 6   727  ***[** 610**] NURSING PROGRESS NOTE 7A-7P***\n...  1645712
# 7   728  nsg admit note\nPT TO SICU FROM EW. THIS 27 YO...  1641938
# 8   729  nursing Progress note\nEvents: temp 102.5-bloo...  1645710
# 9   730  Respiratory Care\nPt remains stable on vent, w...  1645109
# 10  731  SICU\n   HPI:\n   69 year old woman, right-han...   510726
# 11  732  TSICU\n   HPI:\n   45y/o left handed M came to...   557576
# 12  733  SICU\n   HPI:\n   Date [**11-27**]  HD 12\n   ...   501468
# 13  734  Chief Complaint:  found down\n   HPI:\n   Mr. ...   675782
# 14  735  24 Hour Events: 80yo M with afib, likely off h...   506460
# 15  736  Chief Complaint: resp failure, stroke, pneumot...   359402
# 16  737  CVICU\n   HPI:\n   47 M with HTN, DM with acut...   613727
# 17  738  SICU\n   HPI:\n   78 F with hx AF, recently st...   566259
# 18  739  SICU\n   HPI:\n   67 yo lady ac onset (7PM) wi...   643661
# 19  740  SICU\n   HPI:\n   68 yo F of unclear handednes...   588359
# 20  741  TITLE:\n   BEDSIDE SWALLOWING EVALUATION:\n   ...   595675
# 21  742  TITLE:\n   DEFERRED BEDSIDE SWALLOWING EVALUAT...   622968
# 22  743  TITLE:  BEDSIDE SWALLOWING EVALUATION:\nHISTOR...   692512
# 23  744  Attending Physician:  [**Name10 (NameIs) 590**...   645793
# 24  745  TITLE:  BEDSIDE SWALLOWING EVALUATION:\nHISTOR...   510745
# 25  746  TITLE: PT/Rehab Services\n   Consult received....   616126
# 26  747  Attending Physician: [**Name10 (NameIs) **]\n ...   731363
# 27  748  TITLE:\nBEDSIDE SWALLOWING EVALUATION:\nHISTOR...   613747
# 28  749  History\n   Attending M.D.: [**Doctor Last Nam...   527525
# 29  750  Attempted to follow up with patient for PT eva...   359672
# 30  751  Social Work:\n   Consult rec\nd from nsg staff...   614043
# 31  752  Social Work:\n   Covering for [**First Name8 (...   466229
# 32  753  SW consulted to participate in family/team mee...   469648
# 33  754  Met with pt\ns husband in response to request ...   701395
# 34  755  Social Work:\n   Spoke with RNCM who was able ...   360026
# 35  756  Family Information\n   Next of [**Doctor First...   554088
# 36  757  Social Work:\n   Consult rec\nd from nursing t...   729562
# 37  758  Met with pt\ns 2 sisters and their 2 friends. ...   699018
# 38  759  Family Information\n   Next of [**Doctor First...   662481
# 39  760  Referral received from nursing re: family copi...   485561
#
#     SUBJECT_ID  HADM_ID        CATEGORY  \
# 0        79501   119347         Nursing
# 1        53725   188088         Nursing
# 2        47906   128544         Nursing
# 3        90746   115306         Nursing
# 4        86907   125407         Nursing
# 5        30334   170088   Nursing/other
# 6        29626   150680   Nursing/other
# 7        29300   105082   Nursing/other
# 8        29626   150680   Nursing/other
# 9        29534   112562   Nursing/other
# 10       95340   112846       Physician
# 11       90746   115306       Physician
# 12       86314   176365       Physician
# 13       65502   127178       Physician
# 14       42430   100969       Physician
# 15       28089   135595       Physician
# 16       99282   123195       Physician
# 17       62487   147391       Physician
# 18       77271   148746       Physician
# 19       56963   176069       Physician
# 20       95508   192595  Rehab Services
# 21       69207   120556  Rehab Services
# 22       73074   190770  Rehab Services
# 23       42457   118690  Rehab Services
# 24       95340   112846  Rehab Services
# 25       59226   189005  Rehab Services
# 26       72454   178408  Rehab Services
# 27       99282   123195  Rehab Services
# 28       49499   199736  Rehab Services
# 29       28089   135595  Rehab Services
# 30       99282   123195     Social Work
# 31       81378   147279     Social Work
# 32       90521   195402     Social Work
# 33       43004   141585     Social Work
# 34       28089   135595     Social Work
# 35       72107   198124     Social Work
# 36       85025   119829     Social Work
# 37       65970   118685     Social Work
# 38       66438   125724     Social Work
# 39       90541   124428     Social Work
#
#                                   DESCRIPTION  \
# 0                       Nursing Progress Note
# 1                       Nursing Transfer Note
# 2                       Nursing Progress Note
# 3                       Nursing Progress Note
# 4                       Nursing Transfer Note
# 5                                      Report
# 6                                      Report
# 7                                      Report
# 8                                      Report
# 9                                      Report
# 10                           Intensivist Note
# 11                           Intensivist Note
# 12                           Intensivist Note
# 13          Physician Resident Admission Note
# 14           Physician Surgical Progress Note
# 15          Physician Attending Progress Note
# 16                           Intensivist Note
# 17                           Intensivist Note
# 18                           Intensivist Note
# 19                           Intensivist Note
# 20              Bedside Swallowing Evaluation
# 21  Deferred Swallowing & Aphasia Evaluations
# 22              Bedside Swallowing Evaluation
# 23           Physical Therapy Evaluation Note
# 24              Bedside Swallowing Evaluation
# 25                               Generic Note
# 26           Physical Therapy Evaluation Note
# 27                 Bedside Swallow Evaluation
# 28       Occupational Therapy Evaluation Note
# 29              Physical Therapy Contact Note
# 30                  Social Work Progress Note
# 31                  Social Work Progress Note
# 32                  Social Work Progress Note
# 33                  Social Work Progress Note
# 34                  Social Work Progress Note
# 35                 Social Work Admission Note
# 36                  Social Work Progress Note
# 37                  Social Work Progress Note
# 38                 Social Work Admission Note
# 39                  Social Work Progress Note
#
#                                         DESCRIPTION_1  DRG_CODE  \
# 0   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        65
# 1   ACUTE ISCHEMIC STROKE W USE OF THROMBOLYTIC AG...        63
# 2   ACUTE ISCHEMIC STROKE W USE OF THROMBOLYTIC AG...        61
# 3   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 4   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 5   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 6   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 7   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        65
# 8   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 9   INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 10  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 11  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 12  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 13  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 14  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 15  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 16  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 17  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 18  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        65
# 19  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 20  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 21  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 22  ACUTE ISCHEMIC STROKE W USE OF THROMBOLYTIC AG...        61
# 23  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        66
# 24  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 25  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 26  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        65
# 27  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 28  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 29  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 30  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 31  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 32  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        65
# 33  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 34  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 35  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 36  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 37  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 38  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
# 39  INTRACRANIAL HEMORRHAGE OR CEREBRAL INFARCTION...        64
#
#                                                 label Comments
# 0   [[280, 296, PROGNOSIS: Negative], [346, 380, E...       []
# 1                 [[1154, 1178, PROGNOSIS: Positive]]       []
# 2                                                  []       []
# 3                 [[1746, 1774, PROGNOSIS: Negative]]       []
# 4   [[1010, 1018, PATIENT: Negative], [1023, 1049,...       []
# 5                                                  []       []
# 6   [[619, 651, PROGNOSIS: Negative], [1477, 1492,...       []
# 7                                                  []       []
# 8                    [[1328, 1354, FAMILY: Positive]]       []
# 9                                                  []       []
# 10                                                 []       []
# 11                                                 []       []
# 12  [[572, 596, PROGNOSIS: Negative], [8143, 8193,...       []
# 13                                                 []       []
# 14                                                 []       []
# 15                   [[5529, 5555, FAMILY: Negative]]       []
# 16                                                 []       []
# 17                                                 []       []
# 18                                                 []       []
# 19                                                 []       []
# 20                                                 []       []
# 21                                                 []       []
# 22                                                 []       []
# 23  [[2938, 2955, PROGNOSIS: Positive], [2970, 301...       []
# 24                                                 []       []
# 25                                                 []       []
# 26  [[3735, 3781, PROGNOSIS: Negative], [3795, 381...       []
# 27                                                 []       []
# 28                [[3821, 3854, PROGNOSIS: Negative]]       []
# 29                                                 []       []
# 30  [[532, 558, FAMILY: Positive], [566, 587, FAMI...       []
# 31  [[212, 250, EVENT: Family/Goals of Care Meetin...       []
# 32  [[116, 140, EVENT: Family/Goals of Care Meetin...       []
# 33                    [[197, 217, PATIENT: Negative]]       []
# 34                [[2914, 2968, PROGNOSIS: Negative]]       []
# 35  [[1798, 1851, PATIENT: Positive], [2324, 2351,...       []
# 36  [[500, 555, FAMILY: Negative], [780, 799, PROG...       []
# 37                  [[133, 151, PROGNOSIS: Negative]]       []
# 38  [[746, 772, PROGNOSIS: Negative], [778, 797, P...       []
# 39  [[87, 109, PROGNOSIS: Negative], [125, 139, PR...       []

# %%
kalaila_df.ROW_ID.nunique()
# Out:
# 40

# %%
aarti_df = pd.read_json(os.path.join(base_dir, 'aarti.jsonl'), lines=True)

aarti_list = []

for i, data in aarti_df.iterrows():
    note_obj = ClinicalNote(data, label_dict)
    note_obj.parse_label()
    note_obj.binarize_labels()

    aarti_list.append(note_obj.binary_label_dict)

# %%
liam_df = pd.read_json(os.path.join(base_dir, 'liam.jsonl'), lines=True)

liam_list = []

for i, data in liam_df.iterrows():
    note_obj = ClinicalNote(data, label_dict)
    note_obj.parse_label()
    note_obj.binarize_labels()

    liam_list.append(note_obj.binary_label_dict)

# %%
def compare_binary_labels(ann1, ann2):
    # Extracting the list of keys from the first dictionary as all dictionaries are assumed to have the same keys
    keys = ann1[0].keys()

    # Calculating Cohen's Kappa for each key
    kappa_scores = {}
    for key in keys:
        ratings1 = [dic[key] for dic in ann1]
        ratings2 = [dic[key] for dic in ann2]
        kappa = cohen_kappa_score(ratings1, ratings2)
        kappa_scores[key] = kappa

    # Print Cohen's Kappa scores for each class
    for key, kappa in kappa_scores.items():
        print(f"Cohen's Kappa for {key}: {kappa:.2f}")

    return kappa_scores

# %%
_ = compare_binary_labels(kalaila_list, aarti_list)
# Out:
# Cohen's Kappa for FAMILY: Positive: 0.12
# Cohen's Kappa for FAMILY: Negative: 0.19
# Cohen's Kappa for PROGNOSIS: Positive: 0.64
# Cohen's Kappa for PROGNOSIS: Negative: 0.42
# Cohen's Kappa for PATIENT: Positive: -0.06
# Cohen's Kappa for PATIENT: Negative: -0.06
# Cohen's Kappa for EVENT: Family/Goals of Care Meeting: 0.83
# Cohen's Kappa for EVENT: Care Withdrawn/Comfort Measures Only: 0.00

# %%
_ = compare_binary_labels(kalaila_list, liam_list)
# Out:
# Cohen's Kappa for FAMILY: Positive: 0.09
# Cohen's Kappa for FAMILY: Negative: 0.47
# Cohen's Kappa for PROGNOSIS: Positive: 0.84
# Cohen's Kappa for PROGNOSIS: Negative: 0.41
# Cohen's Kappa for PATIENT: Positive: 0.00
# Cohen's Kappa for PATIENT: Negative: -0.05
# Cohen's Kappa for EVENT: Family/Goals of Care Meeting: 0.40
# Cohen's Kappa for EVENT: Care Withdrawn/Comfort Measures Only: 0.79

# %%
_ = compare_binary_labels(liam_list, aarti_list)
# Out:
# Cohen's Kappa for FAMILY: Positive: 0.58
# Cohen's Kappa for FAMILY: Negative: 0.46
# Cohen's Kappa for PROGNOSIS: Positive: 0.79
# Cohen's Kappa for PROGNOSIS: Negative: 0.44
# Cohen's Kappa for PATIENT: Positive: 0.00
# Cohen's Kappa for PATIENT: Negative: 0.36
# Cohen's Kappa for EVENT: Family/Goals of Care Meeting: 0.40
# Cohen's Kappa for EVENT: Care Withdrawn/Comfort Measures Only: 0.00

# %%
import customtkinter

customtkinter.CTkTextbox.tag_config
